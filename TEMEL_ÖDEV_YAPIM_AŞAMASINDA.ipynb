# %% [markdown]
# ###### Temel Ödev

# %%
import colorama
from colorama import Fore, Back, Style

print(Fore.CYAN + Style.BRIGHT +"","~ TEMEL ÖDEV HESAPLAMA PROGRAMI ~","\n\n",sep="                                              ")

print(Style.RESET_ALL)

    
print("Hangi ödevi kulanacaksınız.\n1 =>  1.Temel ödev \n2 =>  2.Temel ödev \n3 =>  3.Temel ödev \n4 =>  4.Temel ödev ")

cevap=(input("lütfen hangi ödevde işlem yapacagınızı belirtin. \n{'1','2','3','4'} değerlerinden birini giriniz "))

#BİRİNCİ ÖDEV
if cevap=='1':
    print (" ")
    
    
    
    
    
#İKİNCİ ÖDEV
elif cevap=='2':
     print (" ")
    

    
    
    
    
#ÜÇÜNCÜ ÖDEV
elif cevap=='3':
     print (" ")
    
    
    
    
    
    

#DÖRDÜNCÜ ÖDEV
elif cevap=='4':
     print ("")
    
    
    
#HATA
else:
    print("\nGirdiğiniz cevap: ", cevap)
    print("Gülüm!!!\nprogramın çalışması için, cevap olarak {1,2,3,4} bunlardan birini girmen lazım. \nokuyarak mı cevap versen ;)")
# Out:
#                                               ~ TEMEL ÖDEV HESAPLAMA PROGRAMI ~
#
#
#
# Hangi ödevi kulanacaksınız.
# 1 =>  1.Temel ödev
# 2 =>  2.Temel ödev
# 3 =>  3.Temel ödev
# 4 =>  4.Temel ödev
# lütfen hangi ödevde işlem yapacagınızı belirtin.
# {'1','2','3','4'} değerlerinden birini giriniz 6
#
# Girdiğiniz cevap:  6
# Gülüm!!!
# programın çalışması için, cevap olarak {1,2,3,4} bunlardan birini girmen lazım.
# okuyarak mı cevap versen ;)

# %% [markdown]
# ##### 1. TEMEL ÖDEV

# %%
#### 1111111111111111



###############################################################################################################################
###############################################################################################################################


import colorama
from colorama import Fore, Back, Style
import math

### çıktıda kullanılır
def uzun_çev(yunus1,adı1,yunus2,adı2):
    import colorama
    from colorama import Fore, Back, Style

    birim=input(Fore.GREEN + Style.BRIGHT + f" {adı1} ve  {adı2}\n           değerlerini hangi birimde çıktı vermemizi arzu edersiniz: \n\nmm  => Milimetre\ncm  => Santimetre\ndm  => Desimetre\nm   => Metre\ndam => Dekametre\nhm  => Hekzametre\nkm  => Kilometre\n\n"+Style.RESET_ALL)
    if birim=='mm':
        yunus1=round(yunus1*1000,yuvarla)
        print(f"{adı1}   =>    " + Fore.BLUE + Style.BRIGHT + str(yunus1) + Style.RESET_ALL + f" {birim}'dir'\n")
        yunus2=round(yunus2*1000,yuvarla)
        print(f"{adı2}   =>    " + Fore.BLUE + Style.BRIGHT + str(yunus2) + Style.RESET_ALL + f" {birim}'dir'\n")
                
    elif birim=='cm':
        yunus1=round(yunus1*100,yuvarla)
        print(f"{adı1}   =>    " + Fore.BLUE + Style.BRIGHT + str(yunus1) + Style.RESET_ALL + f" {birim}'dir'\n")
        yunus2=round(yunus2*100,yuvarla)
        print(f"{adı2}   =>    " + Fore.BLUE + Style.BRIGHT + str(yunus2) + Style.RESET_ALL + f" {birim}'dir'\n")
        
    elif birim=='dm':
        yunus1=round(yunus1*10,yuvarla)
        print(f"{adı1}   =>    " + Fore.BLUE + Style.BRIGHT + str(yunus1) + Style.RESET_ALL + f" {birim}'dir'\n")
        yunus2=round(yunus2*10,yuvarla)
        print(f"{adı2}   =>    " + Fore.BLUE + Style.BRIGHT + str(yunus2) + Style.RESET_ALL + f" {birim}'dir'\n")
        
    elif birim=='m':
        yunus1=round(yunus1*1,yuvarla)
        print(f"{adı1}   =>    " + Fore.BLUE + Style.BRIGHT + str(yunus1) + Style.RESET_ALL + f" {birim}'dir'\n")
        yunus2=round(yunus2*1,yuvarla)
        print(f"{adı2}   =>    " + Fore.BLUE + Style.BRIGHT + str(yunus2) + Style.RESET_ALL + f" {birim}'dir'\n")
        
    elif birim=='dam':
        yunus1=round(yunus1*0.1,yuvarla)
        print(f"{adı1}   =>    " + Fore.BLUE + Style.BRIGHT + str(yunus1) + Style.RESET_ALL + f" {birim}'dir'\n")
        yunus2=round(yunus2*0.1,yuvarla)
        print(f"{adı2}   =>    " + Fore.BLUE + Style.BRIGHT + str(yunus2) + Style.RESET_ALL + f" {birim}'dir'\n")
        
    elif birim=='hm':
        yunus1=round(yunus1*0.01,yuvarla)
        print(f"{adı1}   =>    " + Fore.BLUE + Style.BRIGHT + str(yunus1) + Style.RESET_ALL + f" {birim}'dir'\n")
        yunus2=round(yunus2*0.01,yuvarla)
        print(f"{adı2}   =>    " + Fore.BLUE + Style.BRIGHT + str(yunus2) + Style.RESET_ALL + f" {birim}'dir'\n")
        
    elif birim=='km':
        yunus1=round(yunus1*0.001,yuvarla)
        print(f"{adı1}   =>    " + Fore.BLUE + Style.BRIGHT + str(yunus1) + Style.RESET_ALL + f" {birim}'dir'\n")
        yunus2=round(yunus2*0.001,yuvarla)
        print(f"{adı2}   =>    " + Fore.BLUE + Style.BRIGHT + str(yunus2) + Style.RESET_ALL + f" {birim}'dir'\n")
        
    else:
        print(Fore.RED+ Style.BRIGHT +"\n","~~X HATA X~~\n","",sep="                                                           ")
        print("\nGirilen birim: ", birim)
        print(Style.RESET_ALL)
        print(Fore.GREEN+ Style.BRIGHT +"\nGülüm!!!\nProgramın çalışması için; birimi {mm,cm,dm,m,hm,dam,km} bunlardan birini girmen lazım." + Style.RESET_ALL+ Fore.BLUE+ Style.NORMAL + " \n\nOkuyarak mı cevap versen \U0001F607.")
        print("  mm  => Milimetre\n  cm  => Santimetre\n  dm  => Desimetre\n  m   => Metre\n  dam => Dekametre\n  hm  => Hekzametre\n  km  => Kilometre\n\n")       
        print(Style.RESET_ALL)
        import sys
        sys.exit()
        



###############################################################################################################################
###############################################################################################################################



print(Fore.CYAN + Style.BRIGHT + "","~  1. TEMEL ÖDEV  ~","\n",sep="                                              ")
print(Style.RESET_ALL)


### verilenler
yA = float(input(Fore.RED + Style.BRIGHT + "Lütfen A noktasının bilinen Y koordinatını \nGiriniz (Ya): "))

xA = float(input(Fore.RED + Style.BRIGHT + "Lütfen A noktasının bilinen X koordinatını \nGiriniz (Xa): "))

AB_mesafe = float(input(Fore.RED + Style.BRIGHT + "Lütfen A noktasından B noktasına ölçülen yatay mesafeyi \nGiriniz (AB mesafe): "))

AB_semt = float(input(Fore.RED + Style.BRIGHT + "Lütfen A noktasından B noktasına ölçülen semt açısını \nGiriniz (AB semt): "))

yuvarla = int(input(Fore.RED + Style.BRIGHT + "\nDİKKAT: TÜM UZUNLUKLAR, GİRİLEN DEĞERE YUVARLANACAKTIR.\n" +Style.RESET_ALL + Fore.BLUE + Style.NORMAL + "(NOT: genel olarak uzunluk birimlerinde 2 hane alınır.)\n\n"+Style.RESET_ALL+Fore.GREEN + Style.BRIGHT + "Lütfen yB ve XB kordinatlarını arzu ettiğiniz ondalık hassasiyetini  \nGiriniz: "+Style.RESET_ALL))




### uzunlukları mm  çevirme 
birim1=input(Fore.RED+ Style.BRIGHT + "kordinat ve mesafe değerlerini hangi birimde girdiniz:"+Style.RESET_ALL+Fore.GREEN+ Style.BRIGHT+" \n\nmm  => Milimetre\ncm  => Santimetre\ndm  => Desimetre\nm   => Metre\ndam => Dekametre\nhm  => Hekzametre\nkm  => Kilometre\n\n"+Style.RESET_ALL)


if birim1=='mm':
    yA=yA*0.001
    xA=xA*0.001
    AB_mesafe=AB_mesafe*0.001
    
elif birim1=='cm':
    yA=yA*0.01
    xA=xA*0.01
    AB_mesafe=AB_mesafe*0.01
    
elif birim1=='dm':
    yA=yA*0.1
    xA=xA*0.1
    AB_mesafe=AB_mesafe*0.1
    
elif birim1=='m':
    yA=yA*1
    xA=xA*1
    AB_mesafe=AB_mesafe*1
       
elif birim1=='dam':
    yA=yA*10
    xA=xA*10
    AB_mesafe=AB_mesafe*10  
        
elif birim1=='hm':
    yA=yA*100
    xA=xA*100
    AB_mesafe=AB_mesafe*100
     
elif birim1=='km':
    yA=yA*1000
    xA=xA*1000
    AB_mesafe=AB_mesafe*1000
    
else:
    print(Fore.RED+ Style.BRIGHT +"\n","~~X HATA X~~\n","",sep="                                                           ")
    print("\nGirilen birim: ", birim1)
    print(Style.RESET_ALL)
    print(Fore.GREEN+ Style.BRIGHT +"\nGülüm!!!\nProgramın çalışması için; birimi {mm,cm,dm,m,hm,dam,km} bunlardan birini girmen lazım." + Style.RESET_ALL+ Fore.BLUE+ Style.NORMAL + " \n\nOkuyarak mı cevap versen \U0001F607.")
    print("  mm  => Milimetre\n  cm  => Santimetre\n  dm  => Desimetre\n  m   => Metre\n  dam => Dekametre\n  hm  => Hekzametre\n  km  => Kilometre\n\n")       
    print(Style.RESET_ALL)
    import sys
    sys.exit()
        
### açıyı radyana çevirme

açı_birimi=input(Fore.RED+ Style.BRIGHT + "AB semt açısını hangi birimde girdiniz:  "+Style.RESET_ALL+Fore.GREEN+ Style.BRIGHT+"\n\nd  => Derece\ng  => Grad\nr  => Radyan\n\n"+Style.RESET_ALL)
import math

if açı_birimi=='d':
    AB_semt=AB_semt*math.pi/180
    
elif açı_birimi=='g':
    AB_semt=AB_semt*math.pi/200
    
elif açı_birimi=='r':
    AB_semt=AB_semt*1

else:
    print(Fore.RED+ Style.BRIGHT +"\n","~~X HATA X~~\n","",sep="                                                           ")
    print("\nGirilen birim: ", açı_birimi)
    print(Style.RESET_ALL)
    print(Fore.GREEN+ Style.BRIGHT +"\nGülüm!!!\nProgramın çalışması için; birimi {d,g,r} bunlardan birini girmen lazım." + Style.RESET_ALL+ Fore.BLUE+ Style.NORMAL + " \n\nOkuyarak mı cevap versen \U0001F607.")
    print("  d  => Derece\n  g  => Grad\n  r  => Radyan\n\n")       
    print(Style.RESET_ALL)
    import sys
    sys.exit()   

        
Dy= AB_mesafe*math.sin(AB_semt)
Dx= AB_mesafe*math.cos(AB_semt)

 
yB = Dy+ yA
xB = Dx +xA

### yazdır..
print(Fore.GREEN + Style.BRIGHT +"\n   1. TEMEL ÖDEV, HESAP SONUÇLARI")

print(Fore.RED + Style.BRIGHT +"<----------------------------------->")
print(Style.RESET_ALL)

uzun_çev(yB,"B noktasının hesaplanan Y koordinatı",xB,"B noktasının hesaplanan X koordinatı")
# Out:
#                                               ~  1. TEMEL ÖDEV  ~
#
#
# Lütfen A noktasının bilinen Y koordinatını
# Giriniz (Ya): 545
# Lütfen A noktasının bilinen X koordinatını
# Giriniz (Xa): 545
# Lütfen A noktasından B noktasına ölçülen yatay mesafeyi
# Giriniz (AB mesafe): 56
# Lütfen A noktasından B noktasına ölçülen semt açısını
# Giriniz (AB semt): 65
#
# DİKKAT: TÜM UZUNLUKLAR, GİRİLEN DEĞERE YUVARLANACAKTIR.
# (NOT: genel olarak uzunluk birimlerinde 2 hane alınır.)
#
# Lütfen yB ve XB kordinatlarını arzu ettiğiniz ondalık hassasiyetini
# Giriniz: 6
# kordinat ve mesafe değerlerini hangi birimde girdiniz:
#
# mm  => Milimetre
# cm  => Santimetre
# dm  => Desimetre
# m   => Metre
# dam => Dekametre
# hm  => Hekzametre
# km  => Kilometre
#
# k
#
#                                                            ~~X HATA X~~
#
#
# Girilen birim:  k
#
#
# Gülüm!!!
# Programın çalışması için; birimi {mm,cm,dm,m,hm,dam,km} bunlardan birini girmen lazım.
#
# Okuyarak mı cevap versen 😇.
#   mm  => Milimetre
#   cm  => Santimetre
#   dm  => Desimetre
#   m   => Metre
#   dam => Dekametre
#   hm  => Hekzametre
#   km  => Kilometre
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\Yunus\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3445: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# ##### 2. TEMEL ÖDEV

# %%
#### 222222222222

################################################################################################################################
################################################################################################################################

import numpy as np

import math

import colorama
from colorama import Fore, Back, Style


### mesafe çıktıda kullanılır
def uzun_çev(yunus1,adı1):
    import colorama
    from colorama import Fore, Back, Style

    birim=input(Fore.GREEN + Style.BRIGHT + f"{adı1} değerlerini hangi birimde çıktı vermemizi arzu edersiniz: \n\nmm  => Milimetre\ncm  => Santimetre\ndm  => Desimetre\nm   => Metre\ndam => Dekametre\nhm  => Hekzametre\nkm  => Kilometre\n\n"+Style.RESET_ALL)
    if birim=='mm':
        yunus1=round(yunus1*1000,yuvarla_m)
        print(f"{adı1}   =>    " + Fore.BLUE + Style.BRIGHT + str(yunus1) + Style.RESET_ALL + f" {birim}'dir'\n")
                   
    elif birim=='cm':
        yunus1=round(yunus1*100,yuvarla_m)
        print(f"{adı1}   =>    " + Fore.BLUE + Style.BRIGHT + str(yunus1) + Style.RESET_ALL + f" {birim}'dir'\n")
       
    elif birim=='dm':
        yunus1=round(yunus1*10,yuvarla_m)
        print(f"{adı1}   =>    " + Fore.BLUE + Style.BRIGHT + str(yunus1) + Style.RESET_ALL + f" {birim}'dir'\n")
        
    elif birim=='m':
        yunus1=round(yunus1*1,yuvarla_m)
        print(f"{adı1}   =>    " + Fore.BLUE + Style.BRIGHT + str(yunus1) + Style.RESET_ALL + f" {birim}'dir'\n")

    elif birim=='dam':
        yunus1=round(yunus1*0.1,yuvarla_m)
        print(f"{adı1}   =>    " + Fore.BLUE + Style.BRIGHT + str(yunus1) + Style.RESET_ALL + f" {birim}'dir'\n")
      
    elif birim=='hm':
        yunus1=round(yunus1*0.01,yuvarla_m)
        print(f"{adı1}   =>    " + Fore.BLUE + Style.BRIGHT + str(yunus1) + Style.RESET_ALL + f" {birim}'dir'\n")
        
    elif birim=='km':
        yunus1=round(yunus1*0.001,yuvarla_m)
        print(f"{adı1}   =>    " + Fore.BLUE + Style.BRIGHT + str(yunus1) + Style.RESET_ALL + f" {birim}'dir'\n")
        
    else:
        print(Fore.RED+ Style.BRIGHT +"\n","~~X HATA X~~\n","",sep="                                                           ")
        print("\nGirilen birim: ", birim)
        print(Style.RESET_ALL)
        print(Fore.GREEN+ Style.BRIGHT +"\nGülüm!!!\nProgramın çalışması için; birimi {mm,cm,dm,m,hm,dam,km} bunlardan birini girmen lazım." + Style.RESET_ALL+ Fore.BLUE+ Style.NORMAL + " \n\nOkuyarak mı cevap versen \U0001F607.")
        print("  mm  => Milimetre\n  cm  => Santimetre\n  dm  => Desimetre\n  m   => Metre\n  dam => Dekametre\n  hm  => Hekzametre\n  km  => Kilometre\n\n")       
        import sys
        sys.exit()
        

### açı çıktısında kullanılır
def açı_çev(yunus1,adı1):
    
    import math
    import colorama
    from colorama import Fore, Back, Style

    açı_birimi=input(Fore.GREEN + Style.BRIGHT + f"{adı1} değerini hangi birimde çıktı vermemizi arzu edersiniz: \n\nd  => Derece\ng  => Grad\nr  => Radyan\n\n"+Style.RESET_ALL)
    
    if açı_birimi=='d':
        yunus1=round((yunus1*180/math.pi),yuvarla_a)
    
    elif açı_birimi=='g':
        yunus1=round((yunus1*200/math.pi),yuvarla_a)
    
    elif açı_birimi=='r':
        yunus1=round((yunus1*1),yuvarla_a)

    else:
        print(Fore.RED+ Style.BRIGHT +"\n","~~X HATA X~~\n","",sep="                                                           ")
        print("\nGirilen birim: ", açı_birimi)
        print(Style.RESET_ALL)
        print(Fore.GREEN+ Style.BRIGHT +"\nGülüm!!!\nProgramın çalışması için; birimi {d,g,r} bunlardan birini girmen lazım." + Style.RESET_ALL+ Fore.BLUE+ Style.NORMAL + " \n\nOkuyarak mı cevap versen \U0001F607.")
        print("  d  => Derece\n  g  => Grad\n  r  => Radyan\n\n")       
        print(Style.RESET_ALL)
        import sys
        sys.exit()
    
    if açı_birimi=="d":
        açı_ç="Derece"
    elif açı_birimi=="g":
        açı_ç="Grad"
    elif açı_birimi=="r":
        açı_ç="Radyan"
    
    print(f"{adı1}   =>    " + Fore.BLUE + Style.BRIGHT + str(yunus1) + Style.RESET_ALL + f" {açı_ç}'dir'\n")

###############################################################################################################################
###############################################################################################################################

print(Fore.CYAN + Style.BRIGHT + "","~  2. TEMEL ÖDEV  ~","\n",sep="                                              ")
print(Style.RESET_ALL)

### verilenler

yA = float(input(Fore.RED + Style.BRIGHT + "Lütfen A noktasının bilinen Y koordinatını \nGiriniz (Ya): "))

xA = float(input(Fore.RED + Style.BRIGHT + "Lütfen A noktasının bilinen X koordinatını \nGiriniz (Xa): "))

yB = float(input(Fore.RED + Style.BRIGHT + "Lütfen B noktasının bilinen Y koordinatını \nGiriniz (Yb): "))

xB = float(input(Fore.RED + Style.BRIGHT + "Lütfen B noktasının bilinen X koordinatını \nGiriniz (Xb): "))

yuvarla_m = int(input(Fore.RED + Style.BRIGHT + "\nDİKKAT: TÜM UZUNLUKLAR, GİRİLEN DEĞERE YUVARLANACAKTIR. \n" +Style.RESET_ALL + Fore.BLUE + Style.NORMAL + "(NOT: genel olarak uzunluk birimlerinde 2 hane alınır.)\n\n"+Style.RESET_ALL+Fore.GREEN + Style.BRIGHT +"Lütfen AB mesafe çıktısını, arzu ettiğiniz ondalık hassasiyetini \nGiriniz: "+Style.RESET_ALL))

yuvarla_a = int(input(Fore.RED + Style.BRIGHT + "\nDİKKAT: TÜM AÇILAR, GİRİLEN DEĞERE YUVARLANACAKTIR.\n" + Style.RESET_ALL + Fore.BLUE + Style.NORMAL +"(NOT: genel olarak açı birimlerinde 4 hane alınır.)\n\n"+Style.RESET_ALL+Fore.GREEN + Style.BRIGHT +"Lütfen AB semt açısını, arzu ettiğiniz ondalık hassasiyetini \nGiriniz: "+Style.RESET_ALL))



### uzunlukları mm  çevirme 
birim1=input(Fore.RED+ Style.BRIGHT + "kordinat değerlerini hangi birimde girdiniz:"+Style.RESET_ALL+Fore.GREEN+ Style.BRIGHT+" \n\nmm  => Milimetre\ncm  => Santimetre\ndm  => Desimetre\nm   => Metre\ndam => Dekametre\nhm  => Hekzametre\nkm  => Kilometre\n\n"+Style.RESET_ALL)


if birim1=='mm':
    yA=yA*0.001
    xA=xA*0.001
    yB=yB*0.001
    xB=xB*0.001
    
elif birim1=='cm':
    yA=yA*0.01
    xA=xA*0.01
    yB=yB*0.01
    xB=xB*0.01
    
elif birim1=='dm':
    yA=yA*0.1
    xA=xA*0.1
    yB=yB*0.1
    xB=xB*0.1
    
elif birim1=='m':
    yA=yA*1
    xA=xA*1
    yB=yB*1
    xB=xB*1
    
elif birim1=='dam':
    yA=yA*10
    xA=xA*10
    yB=yB*10
    xB=xB*10
        
elif birim1=='hm':
    yA=yA*100
    xA=xA*100
    yB=yB*100
    xB=xB*100
    
elif birim1=='km':
    yA=yA*1000
    xA=xA*1000
    yB=yB*1000
    xB=xB*1000
    
else:
    print(Fore.RED+ Style.BRIGHT +"\n","~~X HATA X~~\n","",sep="                                                           ")
    print("\nGirilen birim: ", birim1)
    print(Style.RESET_ALL)
    print(Fore.GREEN+ Style.BRIGHT +"\nGülüm!!!\nProgramın çalışması için; birimi {mm,cm,dm,m,hm,dam,km} bunlardan birini girmen lazım." + Style.RESET_ALL+ Fore.BLUE+ Style.NORMAL + " \n\nOkuyarak mı cevap versen \U0001F607.")
    print("  mm  => Milimetre\n  cm  => Santimetre\n  dm  => Desimetre\n  m   => Metre\n  dam => Dekametre\n  hm  => Hekzametre\n  km  => Kilometre\n\n")       
    print(Style.RESET_ALL)
    import sys
    sys.exit()




Dy= (yB-yA)

Dx= (xB-xA)


### AB mesafe

AB_mesafe= np.sqrt((Dy**2+Dx**2))


#### AB semt

## 1. bölge
if Dy>0 and Dx>0:
        
    AB_semt= (np.arctan(Dy/Dx))
    


## 2. bölge
elif Dy>0 and Dx<0:
    
    AB_semt= (np.arctan(Dy/Dx))+math.pi
    


## 3. bölge    
elif Dy<0 and Dx<0:
    
    AB_semt= (np.arctan(Dy/Dx))+200
    

    
## 4. bölge    
elif Dy<0 and Dx>0:
    
    AB_semt= (np.arctan(Dy/Dx))+400
    
elif Dy== 0 or Dx==0:
    print(Fore.RED+ Style.BRIGHT +"\n","~~X HATA X~~\n","",sep="                                                           ")
    print("Delta Y = yB-yA   =>  " + str(Dy) + "\nDelta X = xB-xA   =>  " + str(Dx))
    print(Fore.RED + Style.BRIGHT + "\nDElta Y veya Delta X'den en az biri sıfıra eşit. girilen değerlerde hata var :/ \nSorunun çözülebilmesi için; değerlerin sıfırdan farklı olması lazım. \n" + Style.RESET_ALL+ Fore.BLUE+ Style.NORMAL + "Tekrar kontrol etmek istermisiniz :) " + Style.RESET_ALL)
    import sys
    sys.exit()
    

### Ab mesafesinin konntrolu    


AB_mesafe_kontrol= Dy/(np.sin(AB_semt))

doğruluk= AB_mesafe_kontrol== AB_mesafe
    
    


    
### yazdır..
print(Fore.GREEN + Style.BRIGHT +"\n   2. TEMEL ÖDEV, HESAP SONUÇLARI")

print(Fore.RED + Style.BRIGHT +"<----------------------------------->")
print(Style.RESET_ALL)



uzun_çev(AB_mesafe,"AB Mesafe")

açı_çev(AB_semt,"AB semt")

if doğruluk==True:
    print(Fore.GREEN+ Style.BRIGHT +"\n","~~> TEBRİKLER <~~\n","",sep="                                                           ") 
    
    print(Fore.GREEN + Style.BRIGHT + "AB mesafe değerinin sağlaması yapıldı. cevaplar aynı :)\n\n\n" + Style.RESET_ALL + Fore.BLUE + Style.NORMAL + "AB mesafe = tan(delta Y/Delta x)..." + " = " + "AB mesafe kontrol = Delta Y*sin(AB semt) \n\n" + str(AB_mesafe) + " = " + str(AB_mesafe_kontrol) + Style.RESET_ALL + "\n")
    
    
elif doğruluk== False:
    print(Fore.GREEN+ Style.BRIGHT +"\n","~~X DİKKAT X~~\n","",sep="                                                           ") 
    print(Fore.RED + Style.BRIGHT + "AB mesafe değerinin sağlaması yapıldı. malesef cevaplar farklı :(\n\n " + Style.RESET_ALL +  " AB mesafe = tan(delta Y/Delta x)... => " + str(AB_mesafe)+ " Grad'tır" + "\n\n  AB mesafe kontrol = Delta Y*sin(AB semt) => "  + str(AB_mesafe_kontrol) +" Grad'tır" + Style.RESET_ALL + "\n")
# Out:
#                                               ~  2. TEMEL ÖDEV  ~
#
#
# Lütfen A noktasının bilinen Y koordinatını
# Giriniz (Ya): 1621.25
# Lütfen A noktasının bilinen X koordinatını
# Giriniz (Xa): 3324.61
# Lütfen B noktasının bilinen Y koordinatını
# Giriniz (Yb): 1712.82
# Lütfen B noktasının bilinen X koordinatını
# Giriniz (Xb): 3388.42
#
# DİKKAT: TÜM UZUNLUKLAR, GİRİLEN DEĞERE YUVARLANACAKTIR.
# (NOT: genel olarak uzunluk birimlerinde 2 hane alınır.)
#
# Lütfen AB mesafe çıktısını, arzu ettiğiniz ondalık hassasiyetini
# Giriniz: 2
#
# DİKKAT: TÜM AÇILAR, GİRİLEN DEĞERE YUVARLANACAKTIR.
# (NOT: genel olarak açı birimlerinde 4 hane alınır.)
#
# Lütfen AB semt açısını, arzu ettiğiniz ondalık hassasiyetini
# Giriniz: 4
# kordinat değerlerini hangi birimde girdiniz:
#
# mm  => Milimetre
# cm  => Santimetre
# dm  => Desimetre
# m   => Metre
# dam => Dekametre
# hm  => Hekzametre
# km  => Kilometre
#
# m
#
#    2. TEMEL ÖDEV, HESAP SONUÇLARI
# <----------------------------------->
#
# AB Mesafe değerlerini hangi birimde çıktı vermemizi arzu edersiniz:
#
# mm  => Milimetre
# cm  => Santimetre
# dm  => Desimetre
# m   => Metre
# dam => Dekametre
# hm  => Hekzametre
# km  => Kilometre
#
# m
# AB Mesafe   =>    111.61 m'dir'
#
# AB semt değerini hangi birimde çıktı vermemizi arzu edersiniz:
#
# d  => Derece
# g  => Grad
# r  => Radyan
#
# g
# AB semt   =>    61.255 Grad'dir'
#
#
#                                                            ~~> TEBRİKLER <~~
#
# AB mesafe değerinin sağlaması yapıldı. cevaplar aynı :)
#
#
# AB mesafe = tan(delta Y/Delta x)... = AB mesafe kontrol = Delta Y*sin(AB semt)
#
# 111.60995027326184 = 111.60995027326184

# %% [markdown]
# ##### 3. TEMEL ÖDEV

# %%
########333333333333333333

################################################################################################################################
################################################################################################################################

import colorama
from colorama import Fore, Back, Style

### açı çıktısında kullanılır
def açı_çev(yunus1,adı1):
    
    import math
    import colorama
    from colorama import Fore, Back, Style

    açı_birimi=input(Fore.GREEN + Style.BRIGHT + f"{adı1} değerini hangi birimde çıktı vermemizi arzu edersiniz: \n\nd  => Derece\ng  => Grad\nr  => Radyan\n\n"+Style.RESET_ALL)
    
    if açı_birimi=='d':
        yunus1=round((yunus1*180/math.pi),yuvarla_a)
    
    elif açı_birimi=='g':
        yunus1=round((yunus1*200/math.pi),yuvarla_a)
    
    elif açı_birimi=='r':
        yunus1=round((yunus1*1),yuvarla_a)

    else:
        print(Fore.RED+ Style.BRIGHT +"\n","~~X HATA X~~\n","",sep="                                                           ")
        print("\nGirilen birim: ", açı_birimi)
        print(Style.RESET_ALL)
        print(Fore.GREEN+ Style.BRIGHT +"\nGülüm!!!\nProgramın çalışması için; birimi {d,g,r} bunlardan birini girmen lazım." + Style.RESET_ALL+ Fore.BLUE+ Style.NORMAL + " \n\nOkuyarak mı cevap versen \U0001F607.")
        print("  d  => Derece\n  g  => Grad\n  r  => Radyan\n\n")       
        print(Style.RESET_ALL)
        import sys
        sys.exit()
    
    if açı_birimi=="d":
        açı_ç="Derece"
    elif açı_birimi=="g":
        açı_ç="Grad"
    elif açı_birimi=="r":
        açı_ç="Radyan"
    
    print(f"{adı1}   =>    " + Fore.BLUE + Style.BRIGHT + str(yunus1) + Style.RESET_ALL + f" {açı_ç}'dir'\n")


################################################################################################################################
################################################################################################################################


print(Fore.CYAN + Style.BRIGHT + "","~  3. TEMEL ÖDEV  ~","\n",sep="                                              ")
print(Style.RESET_ALL)


### verilenler

AB_semt = float(input(Fore.RED + Style.BRIGHT + "Lütfen A noktasından B noktasına ölçülen semt açısını \nGiriniz (AB semt): "))

AB_kırılma = float(input(Fore.RED + Style.BRIGHT + "Lütfen A ile B arasındaki kırılma açısını \nGiriniz (AB kırılma): "))

yuvarla_a = int(input(Fore.RED + Style.BRIGHT + "\nDİKKAT: TÜM AÇILAR, GİRİLEN DEĞERE YUVARLANACAKTIR.\n" + Style.RESET_ALL + Fore.BLUE + Style.NORMAL +"(NOT: genel olarak açı birimlerinde 4 hane alınır.)\n\n"+Style.RESET_ALL+Fore.GREEN + Style.BRIGHT +"Lütfen BC semt açısını, arzu ettiğiniz ondalık hassasiyetini \nGiriniz: "+Style.RESET_ALL))


### açıyı radyana çevirme

açı_birimi=input(Fore.RED+ Style.BRIGHT + "AB semt ve AB kırılma açısını hangi birimde girdiniz:  "+Style.RESET_ALL+Fore.GREEN+ Style.BRIGHT+"\n\nd  => Derece\ng  => Grad\nr  => Radyan\n\n"+Style.RESET_ALL)
import math

if açı_birimi=='d':
    AB_semt=AB_semt*math.pi/180
    AB_kırılma=AB_kırılma*math.pi/180
    
elif açı_birimi=='g':
    AB_semt=AB_semt*math.pi/200
    AB_kırılma=AB_kırılma*math.pi/200
    
elif açı_birimi=='r':
    AB_semt=AB_semt*1
    AB_kırılma=AB_kırılma*1

else:
    print(Fore.RED+ Style.BRIGHT +"\n","~~X HATA X~~\n","",sep="                                                           ")
    print("\nGirilen birim: ", açı_birimi)
    print(Style.RESET_ALL)
    print(Fore.GREEN+ Style.BRIGHT +"\nGülüm!!!\nProgramın çalışması için; birimi {d,g,r} bunlardan birini girmen lazım." + Style.RESET_ALL+ Fore.BLUE+ Style.NORMAL + " \n\nOkuyarak mı cevap versen \U0001F607.")
    print("  d  => Derece\n  g  => Grad\n  r  => Radyan\n\n")       
    print(Style.RESET_ALL)
    import sys
    sys.exit()   


### bc semt açısı

if 0<=AB_semt+AB_kırılma<=200:
    BC_semt = (AB_kırılma+AB_semt)+math.pi



elif 200<AB_semt+AB_kırılma<=400:
    BC_semt = (AB_kırılma+AB_semt)-math.pi


elif 400<AB_semt+AB_kırılma<=600:
    BC_semt = (AB_kırılma+AB_semt)-math.pi


elif 600<AB_semt+AB_kırılma<=800:
    BC_semt = (AB_kırılma+AB_semt)-3*math.pi

else:
    print("kuralay")

    
### yazdır
    
print(Fore.GREEN + Style.BRIGHT +"\n   3. TEMEL ÖDEV, HESAP SONUÇLARI")

print(Fore.RED + Style.BRIGHT +"<----------------------------------->")
print(Style.RESET_ALL)

açı_çev(BC_semt,"B noktasından A noktasına ölçülen semt açı")
# Out:
#                                               ~  3. TEMEL ÖDEV  ~
#
#
# Lütfen A noktasından B noktasına ölçülen semt açısını
# Giriniz (AB semt): 145.4021
# Lütfen A ile B arasındaki kırılma açısını
# Giriniz (AB kırılma): 42.3565
#
# DİKKAT: TÜM AÇILAR, GİRİLEN DEĞERE YUVARLANACAKTIR.
# (NOT: genel olarak açı birimlerinde 4 hane alınır.)
#
# Lütfen BC semt açısını, arzu ettiğiniz ondalık hassasiyetini
# Giriniz: 4
# AB semt ve AB kırılma açısını hangi birimde girdiniz:
#
# d  => Derece
# g  => Grad
# r  => Radyan
#
# g
#
#    3. TEMEL ÖDEV, HESAP SONUÇLARI
# <----------------------------------->
#
# B noktasından A noktasına ölçülen semt açı değerini hangi birimde çıktı vermemizi arzu edersiniz:
#
# d  => Derece
# g  => Grad
# r  => Radyan
#
# g
# B noktasından A noktasına ölçülen semt açı   =>    387.7586 Grad'dir'

# %% [markdown]
# ##### 4. TEMEL ÖDEV

# %%
##################  44444444444444444

################################################################################################################################
################################################################################################################################

import numpy as np
import math
import colorama
from colorama import Fore, Back, Style

### açı çıktısında kullanılır
def açı_çev(yunus1,adı1):
    
    import math
    import colorama
    from colorama import Fore, Back, Style

    açı_birimi=input(Fore.GREEN + Style.BRIGHT + f"{adı1} değerini hangi birimde çıktı vermemizi arzu edersiniz: \n\nd  => Derece\ng  => Grad\nr  => Radyan\n\n"+Style.RESET_ALL)
    
    if açı_birimi=='d':
        yunus1=round((yunus1*180/math.pi),yuvarla_a)
    
    elif açı_birimi=='g':
        yunus1=round((yunus1*200/math.pi),yuvarla_a)
    
    elif açı_birimi=='r':
        yunus1=round((yunus1*1),yuvarla_a)

    else:
        print(Fore.RED+ Style.BRIGHT +"\n","~~X HATA X~~\n","",sep="                                                           ")
        print("\nGirilen birim: ", açı_birimi)
        print(Style.RESET_ALL)
        print(Fore.GREEN+ Style.BRIGHT +"\nGülüm!!!\nProgramın çalışması için; birimi {d,g,r} bunlardan birini girmen lazım." + Style.RESET_ALL+ Fore.BLUE+ Style.NORMAL + " \n\nOkuyarak mı cevap versen \U0001F607.")
        print("  d  => Derece\n  g  => Grad\n  r  => Radyan\n\n")       
        print(Style.RESET_ALL)
        import sys
        sys.exit()
    
    if açı_birimi=="d":
        açı_ç="Derece"
    elif açı_birimi=="g":
        açı_ç="Grad"
    elif açı_birimi=="r":
        açı_ç="Radyan"
    
    print(f"{adı1}   =>    " + Fore.BLUE + Style.BRIGHT + str(yunus1) + Style.RESET_ALL + f" {açı_ç}'dir'\n")


################################################################################################################################
################################################################################################################################

print(Fore.CYAN + Style.BRIGHT + "","~  4. TEMEL ÖDEV  ~","\n",sep="                                              ")
print(Style.RESET_ALL)


### verilenler

yA = float(input(Fore.RED + Style.BRIGHT + "Lütfen A noktasının bilinen Y koordinatını \nGiriniz (Ya): "))

xA = float(input(Fore.RED + Style.BRIGHT + "Lütfen A noktasının bilinen X koordinatını \nGiriniz (Xa): "))

yB = float(input(Fore.RED + Style.BRIGHT + "Lütfen B noktasının bilinen Y koordinatını \nGiriniz (Yb): "))

xB = float(input(Fore.RED + Style.BRIGHT + "Lütfen B noktasının bilinen X koordinatını \nGiriniz (Xb): "))

yC = float(input(Fore.RED + Style.BRIGHT + "Lütfen C noktasının bilinen Y koordinatını \nGiriniz (Yc): "))

xC = float(input(Fore.RED + Style.BRIGHT + "Lütfen C noktasının bilinen X koordinatını \nGiriniz (Xc): "))

yuvarla_a = int(input(Fore.RED + Style.BRIGHT + "\nDİKKAT: TÜM AÇILAR, GİRİLEN DEĞERE YUVARLANACAKTIR.\n" + Style.RESET_ALL + Fore.BLUE + Style.NORMAL +"(NOT: genel olarak açı birimlerinde 4 hane alınır.)\n\n"+Style.RESET_ALL+Fore.GREEN + Style.BRIGHT +"Lütfen B ile c arasındaki kırılma açısını, arzu ettiğiniz ondalık hassasiyetini \nGiriniz: "+Style.RESET_ALL))


### uzunlukları mm  çevirme 
birim1=input(Fore.RED+ Style.BRIGHT + "kordinat değerlerini hangi birimde girdiniz:"+Style.RESET_ALL+Fore.GREEN+ Style.BRIGHT+" \n\nmm  => Milimetre\ncm  => Santimetre\ndm  => Desimetre\nm   => Metre\ndam => Dekametre\nhm  => Hekzametre\nkm  => Kilometre\n\n"+Style.RESET_ALL)


if birim1=='mm':
    yA=yA*0.001
    xA=xA*0.001
    yB=yB*0.001
    xB=xB*0.001
    yC=yC*0.001
    xC=xC*0.001
    
elif birim1=='cm':
    yA=yA*0.01
    xA=xA*0.01
    yB=yB*0.01
    xB=xB*0.01
    yC=yC*0.01
    xC=xC*0.01
    
elif birim1=='dm':
    yA=yA*0.1
    xA=xA*0.1
    yB=yB*0.1
    xB=xB*0.1
    yC=yC*0.1
    xC=xC*0.1
    
elif birim1=='m':
    yA=yA*1
    xA=xA*1
    yB=yB*1
    xB=xB*1
    yC=yC*1
    xC=xC*1
    
elif birim1=='dam':
    yA=yA*10
    xA=xA*10
    yB=yB*10
    xB=xB*10
    yC=yC*10
    xC=xC*10
        
elif birim1=='hm':
    yA=yA*100
    xA=xA*100
    yB=yB*100
    xB=xB*100
    yC=yC*100
    xC=xC*100
    
elif birim1=='km':
    yA=yA*1000
    xA=xA*1000
    yB=yB*1000
    xB=xB*1000
    yC=yC*1000
    xC=xC*1000
    
else:
    print(Fore.RED+ Style.BRIGHT +"\n","~~X HATA X~~\n","",sep="                                                           ")
    print("\nGirilen birim: ", birim1)
    print(Style.RESET_ALL)
    print(Fore.GREEN+ Style.BRIGHT +"\nGülüm!!!\nProgramın çalışması için; birimi {mm,cm,dm,m,hm,dam,km} bunlardan birini girmen lazım." + Style.RESET_ALL+ Fore.BLUE+ Style.NORMAL + " \n\nOkuyarak mı cevap versen \U0001F607.")
    print("  mm  => Milimetre\n  cm  => Santimetre\n  dm  => Desimetre\n  m   => Metre\n  dam => Dekametre\n  hm  => Hekzametre\n  km  => Kilometre\n\n")       
    print(Style.RESET_ALL)
    import sys
    sys.exit()



Dy_AB= (yB-yA)
Dx_AB= (xB-xA)


Dy_AC= (yC-yA)
Dx_AC= (xC-xA)



#### AB semt

## 1. bölge
if Dy_AB>0 and Dx_AB>0:
    
    AB_semt=np.arctan(Dy_AB/Dx_AB)
    


## 2. bölge
elif Dy_AB>0 and Dx_AB<0:
    
    AB_semt= (np.arctan(Dy_AB/Dx_AB))+math.pi
    


## 3. bölge    
elif Dy_AB<0 and Dx_AB<0:
    
    AB_semt= (np.arctan(Dy_AB/Dx_AB))+math.pi
    

    
## 4. bölge    
elif Dy_AB<0 and Dx_AB>0:
    
    AB_semt= (np.arctan(Dy_AB/Dx_AB))+2*math.pi
    




#### AC semt

## 1. bölge
if Dy_AC>0 and Dx_AC>0:
    
    AC_semt= (np.arctan(Dy_AC/Dx_AC))
    


## 2. bölge
elif Dy_AC>0 and Dx_AC<0:
    
     AC_semt= (np.arctan(Dy_AC/Dx_AC))+math.pi
    


## 3. bölge    
elif Dy_AC<0 and Dx_AC<0:
    
     AC_semt= (np.arctan(Dy_AC/Dx_AC))+math.pi
    

    
## 4. bölge    
elif Dy_AC<0 and Dx_AC>0:
    
     AC_semt= (np.arctan(Dy_AC/Dx_AC))+2*math.pi
    

    

### yazdır..
print(Fore.GREEN + Style.BRIGHT +"\n   4. TEMEL ÖDEV, HESAP SONUÇLARI")

print(Fore.RED + Style.BRIGHT +"<----------------------------------->")
print(Style.RESET_ALL)




### b den c ye giden kırılma açısı
açı = AC_semt - AB_semt



if açı >0:
    açı_çev(açı,"B ile c arasındaki kırılma açısı")
    

elif açı< 0:
    açı_2 =AC_semt - AB_semt+400
    
    açı_çev(açı_2,"B ile c arasındaki kırılma açısı")

else:
    print("kuralay")
# Out:
#                                               ~  4. TEMEL ÖDEV  ~
#
#
# Lütfen A noktasının bilinen Y koordinatını
# Giriniz (Ya): 1621.25
# Lütfen A noktasının bilinen X koordinatını
# Giriniz (Xa): 2354.61
# Lütfen B noktasının bilinen Y koordinatını
# Giriniz (Yb): 1712.82
# Lütfen B noktasının bilinen X koordinatını
# Giriniz (Xb): 2788.22
# Lütfen C noktasının bilinen Y koordinatını
# Giriniz (Yc): 1902.33
# Lütfen C noktasının bilinen X koordinatını
# Giriniz (Xc): 2212.42
#
# DİKKAT: TÜM AÇILAR, GİRİLEN DEĞERE YUVARLANACAKTIR.
# (NOT: genel olarak açı birimlerinde 4 hane alınır.)
#
# Lütfen B ile c arasındaki kırılma açısını, arzu ettiğiniz ondalık hassasiyetini
# Giriniz: 4
# kordinat değerlerini hangi birimde girdiniz:
#
# mm  => Milimetre
# cm  => Santimetre
# dm  => Desimetre
# m   => Metre
# dam => Dekametre
# hm  => Hekzametre
# km  => Kilometre
#
# m
#
#    4. TEMEL ÖDEV, HESAP SONUÇLARI
# <----------------------------------->
#
# B ile c arasındaki kırılma açısı değerini hangi birimde çıktı vermemizi arzu edersiniz:
#
# d  => Derece
# g  => Grad
# r  => Radyan
#
# g
# B ile c arasındaki kırılma açısı   =>    116.5655 Grad'dir'

# %% [markdown]
# ##### SORUNUN CEVABINI ÇIKTI OLARAK WORD DOSYASINA EKLME

# %%
############ 1111111111111111111 word

! pip install python-docx


from docx import Document
from docx.shared import Inches

document = Document()

document.add_heading('TEMEL ÖDEV', 0)

p = document.add_paragraph('temel ödevin sonuçlarına  ')
p.add_run('aşağıdan').bold = True
p.add_run(' ulaşabilirsiniz.')
p.add_run('\n\nmaile adresimiz : temelodev@gmail.com').italic = True

document.add_heading('TEMEL ÖDEV 1', level=1)

document.add_paragraph('Programa Girilen Değerler', style='Intense Quote')

document.add_paragraph(f"A noktasının bilinen Y koordinatı => {yA} metredir" , style ='List Bullet')
document.add_paragraph(f"A noktasının bilinen X koordinatı => {xA} metredir", style='List Bullet')
document.add_paragraph(f"A noktasından B noktasına ölçülen yatay mesafe =>  {AB_mesafe} Metredir", style='List Bullet')
document.add_paragraph(f"A noktasından B noktasına ölçülen semt açısı => {AB_semt} Gradtır", style='List Bullet')
document.add_paragraph(f"yB ve XB kordinatlarını arzu ettiğiniz ondalık hassasiyet birimi => {birim1}", style='List Bullet')




document.add_paragraph('Cevap', style='Intense Quote')

document.add_paragraph(
    'girilen değerler', style='List Bullet'
)
document.add_paragraph(
    'girilen değerler 1', style='List Number'
)

document.add_picture('zfoto.jpeg', width=Inches(1.25))

records = (
    ( "Ya", str("bir" )),
    ( "Xa",str("iki"))
)

table = document.add_table(rows=1, cols=2)
hdr_cells = table.rows[0].cells
hdr_cells[0].text = 'açı'
hdr_cells[1].text = 'm'
for qty, id in records:
    row_cells = table.add_row().cells
    row_cells[0].text = str(qty)
    row_cells[1].text = id

document.add_page_break()

document.save('cevap.docx')
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: python-docx in c:\users\yunus tuncer\appdata\roaming\python\python38\site-packages (0.8.11)
# Requirement already satisfied: lxml>=2.3.2 in c:\users\yunus\anaconda3\lib\site-packages (from python-docx) (4.6.3)

# %% [markdown]
# ##### cevapları sadece str olarak istiyenlere , cevabı mesaj olarak yollama

# %%
#### maile gönder. eksiz

import colorama
from colorama import Fore, Back, Style

import smtplib

### maili kim gönderiyor, şifresi ne
p_maili= "temelodev@gmail.com"
p_mail_şifresi= "baybora7221"

### servera bağlan, serverı başlat
server= smtplib.SMTP("smtp.gmail.com",587)
server.starttls()

### servera giriş yap. NOT: giriş yapabilmek için gmail güvenlik ayarlarını unutma
server.login(p_maili, p_mail_şifresi)


### konu baş. ,mesaj, isim
template = """subject:{}

{}


{}
"""

### konu başlığı
subject = "ödev hakkında"

### mesaj
mesaj= "mesjı yaz"

### isim
isim = "Yunus Tuncer"


try:
    mail= template.format(subject, mesaj, isim)
    
    ### mesaj kime gidecek
    kime = str(input(Fore.CYAN + Style.BRIGHT + "Lütfen mesaji ileteceğimiz mail adresini \nGiriniz : "+Style.RESET_ALL))
    
    
    while not(("@" in kime) and ("." in kime)):
        print(Fore.RED + Style.BRIGHT +"\n  GEÇERSİZ E-POSTA ADRESİ"+Style.RESET_ALL)
        
        kime = str(input(Fore.BLUE + Style.NORMAL + " (iptal etmek isterseniz 'iptal' yazın) \n\n"+Style.RESET_ALL + Fore.RED + Style.BRIGHT+"Lütfen mesaji ileteceğimiz mail adresini tekrardan \nGiriniz : "+Style.RESET_ALL))
        
        if kime== "iptal":
            break
        
    else:
        server.sendmail(p_maili,kime, mail.encode("utf-8"))
        
        print(Fore.GREEN + Style.BRIGHT + "\nsorunun cevapları başarıyle iletildi" + Style.RESET_ALL)
    
except:
    print(Fore.RED + Style.BRIGHT +'\ngirilen e postayı kontrol edin' + Style.RESET_ALL)
# Out:
# Lütfen mesaji ileteceğimiz mail adresini
# Giriniz : kuralay7221@gmail.com
#
# sorunun cevapları başarıyle iletildi

# %% [markdown]
# ##### oluşturulan word dosyasını istiyen kişiye mail olarak yollama

# %%
#### maile gönder. ekli

import colorama
from colorama import Fore, Back, Style

import smtplib

from email.message import EmailMessage
message = EmailMessage()

### mesaj kime gidecek
kime = str(input(Fore.CYAN + Style.BRIGHT + "Lütfen mesaji ileteceğimiz mail adresini \nGiriniz : "+Style.RESET_ALL))


while not(("@" in kime) and ("." in kime)):
    print(Fore.RED + Style.BRIGHT +"\n  GEÇERSİZ E-POSTA ADRESİ"+Style.RESET_ALL)
    
    kime = str(input(Fore.BLUE + Style.NORMAL + " (iptal etmek isterseniz 'iptal' yazın) \n\n"+Style.RESET_ALL + Fore.RED + Style.BRIGHT+"Lütfen mesaji ileteceğimiz mail adresini tekrardan \nGiriniz : "+Style.RESET_ALL))
    
    if kime== "iptal":
        break
    

    
### maile gönderen ve alan hesaplar
gönderen = "temelodev@gmail.com"
alan = kime
message['From'] = gönderen
message['To'] = alan

### mailin konu başlığı
message['Subject'] = 'konu başlığı'

### mailde gönderilecek mesaj
mesaj = """merhaba

mesaj yaz"""

message.set_content(mesaj)



### dosyanın ismi
dosya= "cevap.docx"



import mimetypes
mime_type, _ = mimetypes.guess_type(dosya)
### print(mime_type)


mime_type, mime_subtype = mime_type.split('/')



with open(dosya, 'rb') as file:
    message.add_attachment(file.read(),maintype=mime_type,subtype=mime_subtype,filename=dosya)
    
try:
    ### print(message)
    mail_server = smtplib.SMTP_SSL('smtp.gmail.com')
    mail_server.set_debuglevel(1)
    mail_server.login(gönderen, 'baybora7221') ## maili gönderen hesap ve şifresi. NOT: giriş yapabilmek için gmail güvenlik ayarlarını unutma
    mail_server.send_message(message)
    mail_server.quit()
    print(Fore.GREEN + Style.BRIGHT + "\nsorunun cevapları başarıyle iletildi" + Style.RESET_ALL)
    
    
except:
    print(Fore.RED + Style.BRIGHT +'\ngirilen e postayı kontrol edin' + Style.RESET_ALL)
# Out:
# Lütfen mesaji ileteceğimiz mail adresini
# Giriniz : kuralay7221@gmail.com
# send: 'ehlo [192.168.43.72]\r\n'
# reply: b'250-smtp.gmail.com at your service, [94.235.227.229]\r\n'
# reply: b'250-SIZE 35882577\r\n'
# reply: b'250-8BITMIME\r\n'
# reply: b'250-AUTH LOGIN PLAIN XOAUTH2 PLAIN-CLIENTTOKEN OAUTHBEARER XOAUTH\r\n'
# reply: b'250-ENHANCEDSTATUSCODES\r\n'
# reply: b'250-PIPELINING\r\n'
# reply: b'250-CHUNKING\r\n'
# reply: b'250 SMTPUTF8\r\n'
# reply: retcode (250); Msg: b'smtp.gmail.com at your service, [94.235.227.229]\nSIZE 35882577\n8BITMIME\nAUTH LOGIN PLAIN XOAUTH2 PLAIN-CLIENTTOKEN OAUTHBEARER XOAUTH\nENHANCEDSTATUSCODES\nPIPELINING\nCHUNKING\nSMTPUTF8'
# send: 'AUTH PLAIN AHRlbWVsb2RldkBnbWFpbC5jb20AYmF5Ym9yYTcyMjE=\r\n'
# reply: b'235 2.7.0 Accepted\r\n'
# reply: retcode (235); Msg: b'2.7.0 Accepted'
# send: 'mail FROM:<temelodev@gmail.com> size=98728\r\n'
# reply: b'250 2.1.0 OK he13sm5207ejc.221 - gsmtp\r\n'
# reply: retcode (250); Msg: b'2.1.0 OK he13sm5207ejc.221 - gsmtp'
# send: 'rcpt TO:<kuralay7221@gmail.com>\r\n'
# reply: b'250 2.1.5 OK he13sm5207ejc.221 - gsmtp\r\n'
# reply: retcode (250); Msg: b'2.1.5 OK he13sm5207ejc.221 - gsmtp'
# send: 'data\r\n'
# reply: b'354  Go ahead he13sm5207ejc.221 - gsmtp\r\n'
# reply: retcode (354); Msg: b'Go ahead he13sm5207ejc.221 - gsmtp'
# data: (354, b'Go ahead he13sm5207ejc.221 - gsmtp')
# send: b'From: temelodev@gmail.com\r\nTo: kuralay7221@gmail.com\r\nSubject: konu =?utf-8?b?YmHFn2zEscSfxLE=?=\r\nMIME-Version: 1.0\r\nContent-Type: multipart/mixed; boundary="===============1170239529973282841=="\r\n\r\n--===============1170239529973282841==\r\nContent-Type: text/plain; charset="utf-8"\r\nContent-Transfer-Encoding: 7bit\r\n\r\nmerhaba\r\n\r\nmesaj yaz\r\n\r\n--===============1170239529973282841==\r\nContent-Type: application/vnd.openxmlformats-officedocument.wordprocessingml.document\r\nContent-Transfer-Encoding: base64\r\nContent-Disposition: attachment; filename="cevap.docx"\r\nMIME-Version: 1.0\r\n\r\\r\nXIkY0iS5/3z/ ...
# sorunun cevapları başarıyle iletildi
# reply: b'250 2.0.0 OK  1639957991 he13sm5207ejc.221 - gsmtp\r\n'
# reply: retcode (250); Msg: b'2.0.0 OK  1639957991 he13sm5207ejc.221 - gsmtp'
# data: (250, b'2.0.0 OK  1639957991 he13sm5207ejc.221 - gsmtp')
# send: 'quit\r\n'
# reply: b'221 2.0.0 closing connection he13sm5207ejc.221 - gsmtp\r\n'
# reply: retcode (221); Msg: b'2.0.0 closing connection he13sm5207ejc.221 - gsmtp'
